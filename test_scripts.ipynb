# %%
from importlib import reload

# %%
import eda_scripts
data = eda_scripts.get_data('./data/orders.csv')

# %%
reload(eda_scripts)
data_new = eda_scripts.get_features(data)
data_new.head(20)
# Out:
#     delivery_area_id                date  orders_cnt  year   date_date  \
# 0                  0 2021-04-01 10:00:00           9  2021  2021-04-01
# 1                  0 2021-04-01 11:00:00           1  2021  2021-04-01
# 2                  0 2021-04-01 13:00:00           1  2021  2021-04-01
# 3                  0 2021-04-01 14:00:00           1  2021  2021-04-01
# 4                  0 2021-04-01 15:00:00           2  2021  2021-04-01
# 5                  0 2021-04-01 16:00:00           2  2021  2021-04-01
# 6                  0 2021-04-01 18:00:00           3  2021  2021-04-01
# 7                  0 2021-04-01 19:00:00           2  2021  2021-04-01
# 8                  0 2021-04-01 20:00:00           2  2021  2021-04-01
# 9                  0 2021-04-01 21:00:00           1  2021  2021-04-01
# 10                 0 2021-04-02 10:00:00           3  2021  2021-04-02
# 11                 0 2021-04-02 11:00:00           1  2021  2021-04-02
# ...

# %%
data_new[data_new['date_date'] == '2021-05-01']
# Out:
#         delivery_area_id                date  orders_cnt  year   date_date  \
# 325                    0 2021-05-01 10:00:00           2  2021  2021-05-01
# 326                    0 2021-05-01 16:00:00           1  2021  2021-05-01
# 327                    0 2021-05-01 17:00:00           1  2021  2021-05-01
# 328                    0 2021-05-01 18:00:00           5  2021  2021-05-01
# 329                    0 2021-05-01 19:00:00           2  2021  2021-05-01
# ...                  ...                 ...         ...   ...         ...
# 823309               539 2021-05-01 19:00:00           1  2021  2021-05-01
# 848146               566 2021-05-01 16:00:00           1  2021  2021-05-01
# 848147               566 2021-05-01 17:00:00           2  2021  2021-05-01
# 848148               566 2021-05-01 18:00:00           2  2021  2021-05-01
# 882852               592 2021-05-01 10:00:00           1  2021  2021-05-01
#
# ...
